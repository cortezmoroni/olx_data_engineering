# %%
from pyspark.sql import functions as F

# %% [markdown]
# #A camada Silver é responsável pelo tratamento e padronização dos dados.
#
# #Transformações realizadas:
#
# #Remoção de espaços em branco.
#
# #Padronização de colunas textuais.
#
# #Conversão dos tipos de dados.
#
# #Tratamento de valores nulos.
#
# #Remoção de registros sem informações essenciais.
#
# #Eliminação de duplicidades.
#
# #Preparação dos dados para análise.

# %%
#leitura_da_bronze
df_bronze = spark.table("workspace.default.bronze_olx")

#tratamento_camada_bronze

df_silver =(

    df_bronze

    #remover espaços extras
    .withColumn("titulo", F.trim(F.col("titulo")))
     .withColumn("url", F.trim(F.col("url")))
     .withColumn("tipo", F.trim(F.col("tipo")))
    .withColumn("bairro", F.trim(F.col("bairro")))
    .withColumn("cidade", F.trim(F.col("cidade")))
    .withColumn("estado", F.trim(F.col("estado")))
    .withColumn("cep", F.trim(F.col("cep")))
    .withColumn("descricao", F.trim(F.col("descricao")))

    #TRANSFORMAR TEXTOS VAZIOS EM NULL
    .replace("", None)


    #converter as colunas numericas
    .withColumn("preco", F.col("preco").cast("double"))
    .withColumn("quartos", F.col("quartos").cast("double"))
    .withColumn("banheiros", F.col("banheiros").cast("double"))
    .withColumn("garagens", F.col("garagens").cast("double"))
    .withColumn("area_m2", F.col("area_m2").cast("double"))

    #remover somente registros sem informação
    .na.drop(subset = ["titulo", "url"])

    #remove somente registros sem informação
    .dropDuplicates(["url"])

     )
                                

(

   df_silver.write\
    .mode("overwrite")\
    .saveAsTable("workspace.default.silver_real_estate_listings")
   
)

# %%
# %sql
select * from workspace.default.silver_real_estate_listings
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>titulo</th><th>url</th><th>preco</th><th>tipo</th><th>bairro</th><th>cidade</th><th>estado</th><th>cep</th><th>quartos</th><th>banheiros</th><th>garagens</th><th>area_m2</th><th>descricao</th><th>imagens</th></tr></thead><tbody><tr><td>oportunidade locaçâo em Tambaú, para Escritórios,empresas,academias, coworking, escolas,lo</td><td>https://pb.olx.com.br/paraiba/comercio-e-industria/oportunidade-locacao-em-tambau-para-escritorios-empresas-academias-coworking-escolas-lo-1486252955</td><td>26000.0</td><td>Imóvel</td><td>null</td><td>João Pessoa</td><td>PB</td><td>58039-101</td><td>null</td><td>null</td><td>null</td><td>null</td><td>Código do anúncio: KX5CBAV Oportunidade de um imovel destinado a empresas, lojas, escritórios, academias, escolas, cultura inglesa, coworking, estúdio, sendo 11 salas, um primeiro andar com salas e seus respectivos banheiros,  e na parte debaixo uma recepção, piscina, salas e banheiro masculino e feminino respectivamente e uma copa cozinha e elevador. os valores dos iptus são destinados a cada sala, pois tem que somar caso seja locado por inteiro, ou então a Pessoa que locar subloca as salas...</td><td>https://img.olx.com.br/images/25/250679746324066.jpg | https://img.olx.com.br/images/26/265626867584482.jpg | https://img.olx.com.br/images/33/334651140936805.jpg | https://img.olx.com.br/images/39/393610507821393.jpg | https://img.olx.com.br/images/21/216601142503693.jpg | https://img.olx.com.br/images/38/385614380036360.jpg | https://img.olx.com.br/images/39/398626509544798.jpg | https://img.olx.com.br/images/34/349673862544670.jpg | https://img.olx.com.br/images/95/954692262763356.jpg | https://img.olx.com.br/images/25/252684862024825.jpg | https://img.olx.com.br/images/26/261697740253188.jpg | https://img.olx.com.br/images/25/255629382817798.jpg | https://img.olx.com.br/images/25/257646747332966.jpg | https://img.olx.com.br/images/44/444613741550205.jpg | https://img.olx.com.br/images/28/286669024091568.jpg | https://img.olx.com.br/images/40/409608861059207.jpg | https://img.olx.com.br/images/38/380621147576187.jpg | https://img.olx.com.br/images/27/271613620522457.jpg | https://img.olx.com.br/images/19/191659386208808.jpg | https://img.olx.com.br/images/39/399644024620805.jpg</td></tr><tr><td>Apartamento mobiliado no 17 andar</td><td>https://pb.olx.com.br/paraiba/imoveis/apartamento-mobiliado-no-17-andar-1486251330</td><td>3000.0</td><td>Apartamento</td><td>João Pessoa, Jardim OceaniaHoje, 17:12</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>268.0</td><td>null</td><td>null</td></tr><tr><td>Apartamento 4 suítes  - venda ou locação - Campina Grande Mirante</td><td>https://pb.olx.com.br/paraiba/imoveis/apartamento-4-suites-venda-ou-locacao-campina-grande-mirante-1354803643</td><td>1189000.0</td><td>Apartamento</td><td>null</td><td>Campina Grande</td><td>PB</td><td>58407-664</td><td>4.0</td><td>null</td><td>null</td><td>null</td><td>Código do anúncio: jbenicMaraug16E!1fre Apartamento Luxuoso para Locação no Bairro Mirante - Campina Grande Descubra o seu novo lar no coração do bairro Mirante, em Campina Grande! Este magnífico apartamento de 4 quartos, todos suítes, oferece conforto e sofisticação em cada detalhe. Com uma localização privilegiada, você estará próximo a diversas comodidades, incluindo lojas, restaurantes e áreas de lazer. Características do Imóvel: 4 Suítes Amplas: Perfeitas para garantir privacidade e conforto para toda a família. Sala Espetacular: Um espaço arejado e iluminado, ideal para receber amigos e familiares. Cozinha Moderna: Equipada e funcional, perfeita para preparar deliciosas refeições. Varanda: Um espaço aconchegante para relaxar e apreciar a vista do bairro. Diferenciais: Vaga de Garagem: Para maior comodidade e segurança. Condomínio com Estrutura Completa: Área de lazer, piscina e segurança 24h, garantindo tranquili ...
