# %% [markdown]
# #Projeto de Engenharia de dados - Pipeline  Medallion (OLX)
# ##Este projeto demonstra a construção  de um pipeline de engenharia de dados utilizando a arquitetura medallion(BRONZE, SILVER, GOLD).Os dados foram  extraídos  de anuncios de imóveis da OLX  e processamento  em databricks utilizando Pyspark.

# %%
from pyspark.sql import functions as F

# %% [markdown]
# #Extração dos dados  da Olx

# %% [markdown]
# ##O dataset em formaato CSV é carregado para on databricks.O arquivo contém  anúncios  de imóveis  da OLX com informações  como titulo, preço, localização, área , qtd de quartos e demais caracteristicas.

# %%
df =  (

spark.read
.option("header", "true")
.option("inferSchema", "true")
.csv("/Volumes/workspace/default/dados/dataset_olx_raw.csv")
)

# %% [markdown]
# ##BRONZE

# %% [markdown]
# #A camada bronze representa a ingestao dos dados brutos.
# #Nesta etapa:
# # Os Dados sao diretamente do arquivo csv
# #Nenhuma transformação de negócio é aplicada
# #Os dados sao no formato delta lake.
# # O objetivo é preservar a informação original para auditoria e processamento.

# %%
df.write\
    .format("delta")\
    .mode("overwrite")\
    .saveAsTable("workspace.default.bronze_olx")

# %%
# %sql
select * from workspace.default.bronze_olx
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>titulo</th><th>url</th><th>preco</th><th>tipo</th><th>bairro</th><th>cidade</th><th>estado</th><th>cep</th><th>quartos</th><th>banheiros</th><th>garagens</th><th>area_m2</th><th>descricao</th><th>imagens</th></tr></thead><tbody><tr><td>Apartamento com 2 quartos e 60 m² em Tambauzinho</td><td>https://pb.olx.com.br/paraiba/imoveis/apartamento-com-2-quartos-e-60-m-em-tambauzinho-1486265495</td><td>380000.0</td><td>Apartamento</td><td>null</td><td>João Pessoa</td><td>PB</td><td>58042-070</td><td>2.0</td><td>null</td><td>1.0</td><td>60.0</td><td>Código do anúncio: AP1835 Apartamento em Tambauzinho localizado a 100 metros do Espaço Cultural.     Detalhes do imóvel   - 70 m²  - Andar alto  - Nascente sul  - 2 quartos sendo 1 suíte  - Varanda  - 1 vaga     Prédio com portaria 24h, 2 elevadores, salão de festas, piscina e churrasqueira.    Valor de condomínio R$ 550,00    Consulte a disponibilidade e obtenha mais informações através dos contatos abaixo     José Carlos - Creci 4551f  83 99904-5189    Tayrone Nobre - Creci 4445f  83 99955-4141    Busca olx Apartamento com 2 quartos em Tambauzinho.       - Cômodos Área de Serviço, Cozinha, Varanda,     - Infraestrutura Piscina, Salão de Festas,</td><td>https://img.olx.com.br/images/67/677669865595401.jpg | https://